# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
import re

# %%
def get_history(country, from_date='20170924'):
    page = requests.get(f'https://en.wikipedia.org/w/index.php?title={country}_national_soccer_team&offset={from_date}&action=history')
    if page.status_code == 200:
        res = get_revision_link(page)
        if res:
            return res
    
    page = requests.get(f'https://en.wikipedia.org/w/index.php?title={country}_national_football_team&offset={from_date}&action=history')
    if page.status_code == 200:
        res = get_revision_link(page)
        if res:
            return res
    
    page = requests.get(f'https://en.wikipedia.org/w/index.php?title={country}_men%27s_national_soccer_team&offset={from_date}&action=history')
    if page.status_code == 200:
        res = get_revision_link(page)
        if res:
            return res
    
    return False

# %%
def get_revision_link(page):
    soup = bs(page.content, 'html.parser')
    
    page_history = soup.select('ul#pagehistory')
    if len(page_history) < 1:
        return False
    
    first_history = page_history[0].find('li')
    if not first_history:
        return False
    
    revision_link = first_history.select('a.mw-changeslist-date')
    if len(revision_link) < 1:
        return False
    
    revision_data = revision_link[0]
    
    # If the revision isn't very recent, we're possibly at the wrong page
    revision_date = revision_data.text
    if int(revision_date.split(' ')[-1]) < 2017:
        return False
    
    return revision_data['href']

# %%
def extract_players(page):
    soup = bs(page.content, 'html.parser')

    # Get the first table after "Current squad" heading
    squad_heading = soup.find(lambda x: x.name in ['h2', 'h3'] and x.text.startswith('Current squad'))
    if not squad_heading:
        print('Cannot find current squad')
        return False
    squad_table = squad_heading.find_next_sibling('table')
    squad_table_body = squad_table.find('tbody')
    
    # Get the rows of the table and add data to all_players
    rows = squad_table_body.find_all('tr')
    all_players = []
    for row in rows:
        cols = row.find_all(['td', 'th'])
        cols = [c.text.strip() for c in cols]

        if len(cols) < 2:
            continue
        if len(cols) != 7:
            print('Unexpected number of columns')
            continue
        # skip header
        if cols[0] == 'No.':
            continue
        
        # Remove number from position
        cols[1] = re.sub(r"[0-9]", "", cols[1])
        
        # Remove captain/vice-captain from name
        if cols[2].split(' ')[-1].startswith('('):
            cols[2] = ' '.join(cols[2].split(' ')[:-1])

        age_cell = cols[3]
        # Extract age
        try:
            age = re.search(r"\xa0([0-9]+)", age_cell).group(1)
            cols[3] = age
        except:
            cols[3] = age_cell
            print('Match failed')

        # Extract birthday
        try:
            birthday = re.search(r"([0-9]{4}-[0-9]{2}-[0-9]{2})", age_cell).group()
            cols = cols[:3] + [birthday] + cols[3:]
        except:
            cols = cols[:3] + [age_cell] + cols[3:]
            print('Match failed')

        all_players.append(cols)
    
    return all_players

# %%
def create_players_csv(country, dir='teams-2017'):
    print(f'Getting players for {country}')

    country = country.replace(' ', '_')
    
    link = get_history(country)
    if not link:
        print('Error when finding revision history')
        return False
    
    page = requests.get(f'https://en.wikipedia.org/{link}')
    if not page:
        print('Error when retrieving page')
        return False
    
    all_players = extract_players(page)
    if not all_players:
        return False

    country_basename = country.replace(' ', '-').lower()
    with open(f'{dir}/{country_basename}.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['No.', 'Position', 'Player', 'DOB', 'Current age', 'Caps', 'Goals', 'Club'])
        writer.writerows(all_players)
    
    return True

# %%
def create_all_countries():
    failed = []
    with open('all-countries.txt', 'r') as f:
        for line in f.readlines():
            country = line.strip()
            if not create_players_csv(country):
                failed.append(country)

    with open('fail-logs.txt', 'w') as f:
        print('\n'.join(failed), file=f)

# %%
create_all_countries()
# Out:
# Getting players for Iran
# Getting players for Japan
# Getting players for South Korea
# Getting players for Australia
# Getting players for Qatar
# Getting players for United Arab Emirates
# Cannot find current squad
# Getting players for Saudi Arabia
# Getting players for China PR
# Error when finding revision history
# Getting players for Iraq
# Getting players for Syria
# Getting players for Uzbekistan
# Getting players for Lebanon
# Cannot find current squad
# Getting players for Oman
# Getting players for Kyrgyzstan
# Cannot find current squad
# Getting players for Jordan
# Getting players for Vietnam
# Match failed
# Match failed
# Match failed
# Getting players for Palestine
# Getting players for India
# Getting players for Bahrain
# Getting players for Thailand
# Getting players for Tajikistan
# Match failed
# Match failed
# Getting players for North Korea
# Unexpected number of columns
# Getting players for Philippines
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Chinese Taipei
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Turkmenistan
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Myanmar
# Match failed
# Match failed
# Getting players for Hong Kong
# Getting players for Yemen
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Afghanistan
# Getting players for Maldives
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Kuwait
# Getting players for Indonesia
# Getting players for Singapore
# Getting players for Nepal
# Match failed
# Match failed
# Getting players for Malaysia
# Getting players for Cambodia
# Getting players for Macau
# Getting players for Laos
# Cannot find current squad
# Getting players for Bhutan
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Mongolia
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Bangladesh
# Getting players for Guam
# Getting players for Brunei
# Getting players for Timor-Leste
# Cannot find current squad
# Getting players for Pakistan
# Match failed
# Getting players for Sri Lanka
# Match failed
# Match failed
# Unexpected number of columns
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Match failed
# Match failed
# Match failed
# Match failed
# Unexpected number of columns
# Unexpected number of columns
# Match failed
# Match failed
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Match failed
# Match failed
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Senegal
# Getting players for Tunisia
# Getting players for Nigeria
# Getting players for Algeria
# Getting players for Morocco
# Getting players for Egypt
# Getting players for Ghana
# Getting players for Cameroon
# Getting players for DR Congo
# Getting players for Ivory Coast
# Getting players for Mali
# Getting players for Burkina Faso
# Cannot find current squad
# Getting players for South Africa
# Getting players for Guinea
# Getting players for Cape Verde
# Getting players for Uganda
# Match failed
# Match failed
# Getting players for Zambia
# Match failed
# Match failed
# Getting players for Benin
# Getting players for Gabon
# Getting players for Congo
# Match failed
# Match failed
# Getting players for Madagascar
# Getting players for Niger
# Getting players for Libya
# Cannot find current squad
# Getting players for Mauritania
# Getting players for Kenya
# Getting players for Central African Republic
# Getting players for Zimbabwe
# Getting players for Sierra Leone
# Match failed
# Match failed
# Getting players for Mozambique
# Getting players for Namibia
# Getting players for Angola
# Getting players for Guinea-Bissau
# Getting players for Malawi
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Togo
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Sudan
# Getting players for Rwanda
# Getting players for Tanzania
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Equatorial Guinea
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Eswatini
# Getting players for Lesotho
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Comoros
# Getting players for Botswana
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Burundi
# Match failed
# Match failed
# Getting players for Ethiopia
# Getting players for Liberia
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Mauritius
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Gambia
# Getting players for South Sudan
# Match failed
# Match failed
# Getting players for Chad
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for São Tomé and Príncipe
# Getting players for Seychelles
# Cannot find current squad
# Getting players for Djibouti
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Somalia
# Cannot find current squad
# Getting players for Eritrea
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Mexico
# Getting players for United States
# Cannot find current squad
# Getting players for Costa Rica
# Getting players for Jamaica
# Getting players for Honduras
# Getting players for El Salvador
# Getting players for Canada
# Cannot find current squad
# Getting players for Curaçao
# Match failed
# Getting players for Panama
# Getting players for Haiti
# Getting players for Trinidad and Tobago
# Getting players for Antigua and Barbuda
# Getting players for Guatemala
# Getting players for Saint Kitts and Nevis
# Getting players for Suriname
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Nicaragua
# Getting players for Dominican Republic
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Grenada
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Barbados
# Getting players for Guyana
# Match failed
# Match failed
# Getting players for Saint Vincent and the Grenadines
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Bermuda
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Belize
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Saint Lucia
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Puerto Rico
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Cuba
# Getting players for Montserrat
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Dominica
# Getting players for Cayman Islands
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Bahamas
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Aruba
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Turks and Caicos Islands
# Getting players for U.S. Virgin Islands
# Error when finding revision history
# Getting players for British Virgin Islands
# Match failed
# Match failed
# Getting players for Anguilla
# Getting players for Uruguay
# Getting players for Colombia
# Getting players for Peru
# Cannot find current squad
# Getting players for Brazil
# Getting players for Venezuela
# Getting players for Bolivia
# Getting players for Paraguay
# Getting players for Argentina
# Getting players for Chile
# Getting players for Ecuador
# Getting players for New Zealand
# Getting players for Solomon Islands
# Getting players for New Caledonia
# Getting players for Tahiti
# Cannot find current squad
# Getting players for Fiji
# Match failed
# Match failed
# Getting players for Vanuatu
# Match failed
# Match failed
# Getting players for Papua New Guinea
# Getting players for American Samoa
# Getting players for Samoa
# Getting players for Tonga
# Getting players for Cook Islands Unranked
# Error when finding revision history
# Getting players for Belgium
# Getting players for France
# Getting players for England
# Getting players for Portugal
# Getting players for Spain
# Getting players for Italy
# Unexpected number of columns
# Unexpected number of columns
# Getting players for Croatia
# Getting players for Denmark
# Getting players for Germany
# Getting players for Netherlands
# Getting players for Switzerland
# Getting players for Wales
# Getting players for Poland
# Getting players for Sweden
# Getting players for Austria
# Getting players for Ukraine
# Getting players for Serbia
# Getting players for Turkey
# Getting players for Slovakia
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Match failed
# Getting players for Romania
# Getting players for Russia
# Getting players for Hungary
# Getting players for Republic of Ireland
# Getting players for Czech Republic
# Getting players for Norway
# Getting players for Northern Ireland
# Getting players for Iceland
# Getting players for Scotland
# Cannot find current squad
# Getting players for Greece
# Getting players for Finland
# Getting players for Bosnia and Herzegovina
# Getting players for Slovenia
# Getting players for Montenegro
# Getting players for North Macedonia
# Getting players for Albania
# Getting players for Bulgaria
# Cannot find current squad
# Getting players for Israel
# Getting players for Belarus
# Getting players for Georgia
# Getting players for Luxembourg
# Getting players for Armenia
# Getting players for Cyprus
# Getting players for Faroe Islands
# Getting players for Azerbaijan
# Getting players for Estonia
# Getting players for Kosovo
# Getting players for Kazakhstan
# Getting players for Lithuania
# Getting players for Latvia
# Getting players for Andorra
# Getting players for Malta
# Getting players for Moldova
# Getting players for Liechtenstein
# Getting players for Gibraltar
# Getting players for San Marino
